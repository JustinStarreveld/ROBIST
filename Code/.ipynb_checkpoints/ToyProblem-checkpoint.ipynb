# %%
# Import packages
import numpy as np
import cvxpy as cp
import mosek
import time

import phi_divergence as phi
import robust_sampling as rs
import dataio
import util

# %% [markdown]
# The toy model we examine is as follows:
#
# \begin{align}\label{toy_model_2}
#     \begin{split}
#         \max_{\mathbf{x} \geq \mathbf{0}}\{\mathbf{e}^T \mathbf{x}: \mathbb{P}^*(\mathbf{\xi}\in [-1,1]^{k}: \mathbf{\xi}^T \mathbf{x} \leq 1)\geq \beta\}.
#     \end{split}
# \end{align}

# %%
# Problem specific functions:
def generate_data(k, N):
    np.random.seed(1)
    data = np.random.uniform(-1,1,size = (N,k)) # generates N random scenarios    
    return data 

def generate_data_with_nominal(k, N):
    data_nominal = np.array([[0] * k])
    np.random.seed(1)
    data = np.random.uniform(-1,1,size = (N-1,k)) # generate N-1 scenarios
    data = np.concatenate((data_nominal,data)) # add nominal case to training data
    return data

def solve_SCP(S, time_limit):
    k = S.shape[1]
    x = cp.Variable(k, nonneg = True)
    constraints = [(S @ x) - 1 <= 0, cp.sum(x[0:(k-1)]) <= x[k-1]-1, x<=10]
    obj = cp.Maximize(cp.sum(x))
    prob = cp.Problem(obj,constraints)
    try:
        prob.solve(solver=cp.MOSEK, mosek_params = {mosek.dparam.optimizer_max_time: time_limit})
    except cp.error.SolverError:
        return (None, None)
    return (x.value, prob.value)

def uncertain_constraint(S, x):
    return (np.dot(S,x)) - 1

def get_true_prob(x, k):
    return(1/2+1/(2*x[k-1]))
    
def solve_toyproblem_true_prob(beta, k):
    x = cp.Variable(k, nonneg = True)
    constraints = [(1-2*beta)*x[k-1] + 1 >= 0, cp.sum(x[0:(k-1)]) <= x[k-1]-1, x<=10]
    obj = cp.Maximize(cp.sum(x))
    prob = cp.Problem(obj,constraints)
    prob.solve(solver=cp.MOSEK)
    return(x.value, prob.value)

# %%
# Set parameter values
alpha = 10**-6
beta = 0.95
k = 10
N_train = 1000
N_test = 1000
par = 1
phi_div = phi.mod_chi2_cut
phi_dot = 1
time_limit_search = 0.5*60 # in seconds (time provided to search algorithm)
#time_limit_mosek = 10*60 # in seconds (for larger MIP / LP solves)
time_limit_solve = 5*60 # in seconds (for individuals solves of SCP)

max_nr_solutions = 1000 # for easy problems with long time limits, we may want extra restriction
numeric_precision = 1e-6 # To correct for floating-point math operations

# %%
# Get generated data
#N_campi = util.determine_campi_N_min(k, beta, alpha)
#N_train = N_campi
data_train = generate_data_with_nominal(k, N_train)
data_test = generate_data(k, N_test)

# %%
#add_strategy = 'smallest_vio'
#add_strategy = 'N*(beta-lb)_smallest_vio'
add_strategy = 'random_vio'
#add_strategy = 'random_weighted_vio'
remove_strategy = 'random_active'
clean_strategy = 'all_inactive'
random_seed = 1
clean_time_threshold = 0.05*time_limit_search # This determines when clean removals are made
add_remove_threshold = 0.00 # This determines when randomness is introduced in add/removal decision

runtime_search, num_iter, solutions = rs.search_alg(data_train, N_test, beta, alpha, time_limit_search, time_limit_solve, 
                                                   max_nr_solutions, add_strategy, remove_strategy, clean_strategy, 
                                                   add_remove_threshold, clean_time_threshold, 
                                                   par, phi_div, phi_dot, numeric_precision,
                                                   solve_SCP, uncertain_constraint, random_seed)

runtime_eval, best_sol, pareto_solutions = rs.evaluate_alg(solutions, data_test, beta, alpha, par, phi_div, phi_dot, 
                                                           uncertain_constraint, numeric_precision)

# %%
runtime_search
# Out:
# 30.076422929763794

# %%
num_iter
# Out:
# {'add': 137, 'remove': 126, 'clean': 0}

# %%
runtime_eval
# Out:
# 16.96430015563965

# %%
dataio.print_solution_info(best_sol)
# Out:
# obj: 1.145206307152658
# lb_train: 0.9500424323950727
# lb_test: 0.9500424323950727
# time_found: 7.98474907875061
# scenario_set: [0, 83, 513, 828, 727, 169, 468, 150, 418, 175, 393, 632, 682, 619, 955, 773]

# %%
dataio.plot_pareto_curve(pareto_solutions, beta, None, None, None, None, None)

# %%
dataio.plot_obj_over_time(solutions, best_sol, None, None, None, None)

# %%
dataio.plot_size_set_over_time(solutions, best_sol, None, None, None, None)

# %%
# Plot final solution found by algorithm
name = 'Strategy: '+ str(add_strategy)
save_plot = False
plot_type = "eps"
show_legend = True
Z_values = data_train[best_sol['scenario_set']]
dataio.plot_solution(name, data_train, Z_values, best_sol['sol'], 
              best_sol['obj'], best_sol['lb_test'], save_plot, plot_type, show_legend, N, alpha, beta)

# %%
# Compute optimal solution with true probability constraint
prob_true = beta
[x_true, obj_true] = solve_toyproblem_true_prob(prob_true, k)
constr = uncertain_constraint(data_test, x_true)
vio = constr[constr>(0+numeric_precision)]   
p_vio = len(vio)/N_train
p = np.array([1-p_vio, p_vio])
r = phi_dot/(2*N_test)*scipy.stats.chi2.ppf(1-alpha, 1)
lb = rs.compute_lb(p, r, par, phi_div)
print(p)
print(lb)
print(obj_true)
# Out:
# [0.895 0.105]
# 0.8614689962206747
# 1.5000000000066576

# %%
name = "TrueProb="+str(prob_true)
save_plot = False
plot_type = "eps"
show_legend = True
dataio.plot_solution(name, data_test, None, x_true, obj_true, lb, save_plot, plot_type, show_legend, N, alpha, beta)

# %%
# Determine optimal solution given data_test
runtime, opt_x, opt_sum_y, opt_obj, opt_lb = util.compute_opt_given_data(alpha, beta, par, phi_div, data_test, time_limit_mosek)

# %%
runtime
# Out:
# 20.242980480194092

# %%
# Plot optimal solution given data_test
name = 'Opt_given_test_data'
save_plot = False
plot_type = "eps"
show_legend = True
dataio.plot_solution(name, data_test, None, opt_x, opt_obj, opt_lb, save_plot, plot_type, show_legend, N, alpha, beta)

# %%
# Compute solution via Campi method
data = generate_data(k, N_campi)
runtime, campi_x, campi_obj, campi_true_prob, Z_arr = util.solve_with_campi_N(alpha, beta, numeric_precision, data, time_limit_mosek)

# %%
# Plot Campi solution
name = 'Campi method'
save_plot = False
plot_type = "eps"
show_legend = True
dataio.plot_solution(name, data, Z_arr, campi_x, campi_obj, 0, save_plot, plot_type, show_legend, N, alpha, beta)

# %%
[i for i in range(1,10)]
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %% [markdown]
# # The following cells are used to obtain output and write to latex tables

# %% [markdown]
# First we inspect the various strategies that could be employed

# %%
headers = ['k', 'seed', 
           'Obj.~Alg.', 'Obj.~(true prob.)', 'Gap (\%)', 'LB', 'True Prob.', 
           '\#Iter.~(add)', '\#Iter.~(remove)', '\#Iter.~(clean)', '$|\mathcal{X}|$',
           '$|\mathcal{S}_{best}|$', '$|\mathcal{S}_{max}|$', '$|\mathcal{S}_{avg}|$', 'Time until best found']

output_data = {}

# Variable parameter values
k_settings = [10, 100, 1000, 10000]
random_seed_settings = [i for i in range(1, 4)]

N_train = 1000
N_test = 10000
time_limit_search = 1*60

# Fixed parameter values
alpha = 10**-6
beta = 0.95
par = 1
phi_div = phi.mod_chi2_cut
phi_dot = 1
time_limit_mosek = 1*60
time_limit_solve = 1*time_limit_search # in seconds 
max_nr_solutions = 5000 # for easy problems with long time limits, we may want extra restriction
numeric_precision = 1e-6 # To correct for floating-point math operations

# Alg settings
#add_strategy_settings = ['random_vio', 'random_weighted_vio'] 
#remove_strategy_settings = ['random_any', 'random_active']
add_strategy = 'random_vio' #['smallest_vio', 'N*(beta-lb)_smallest_vio', 'random_vio', 'random_weighted_vio']
remove_strategy = 'random_active' #'random_any'
clean_strategy = 'all_inactive'
clean_time_threshold = 0.01*time_limit_search
add_remove_threshold = 0.00 # should be fractional in relation to beta

run_count = 0

for k in k_settings:
    
    x_true, obj_true = solve_toyproblem_true_prob(beta, k)
    data_train = generate_data_with_nominal(k, N_train)
    data_test = generate_data(k, N_test)
    
    for random_seed in random_seed_settings:

        runtime_search, num_iter, solutions = rs.search_alg(data_train, N_test, beta, alpha, time_limit_search, time_limit_solve, 
                                                           max_nr_solutions, add_strategy, remove_strategy, clean_strategy, 
                                                           add_remove_threshold, clean_time_threshold, 
                                                           par, phi_div, phi_dot, numeric_precision,
                                                           solve_SCP, uncertain_constraint, random_seed)

        runtime_eval, best_sol, pareto_solutions = rs.evaluate_alg(solutions, data_test, beta, alpha, par, phi_div, phi_dot, 
                                                 uncertain_constraint, numeric_precision)
        obj_alg = best_sol['obj']
        time_best_found = best_sol['time']
        lb_alg = best_sol['lb_test']
        num_scen_best = len(best_sol['scenario_set'])

        # get num scen avg and max
        num_scen_avg = 0
        num_scen_max = 0
        for sol in solutions:
            num_scen = len(sol['scenario_set'])
            num_scen_avg += num_scen
            if num_scen > num_scen_max:
                num_scen_max = num_scen
        num_sol = len(solutions)
        num_scen_avg = num_scen_avg / num_sol


        x_true_prob = get_true_prob(best_sol['sol'], k)
        obj_gap_true =  100*(obj_true - obj_alg)/obj_true

        output_data[(k, random_seed)] = [f'{round(obj_alg,3):.3f}',
                                              f'{round(obj_true,3):.3f}',
                                              f'{round(obj_gap_true,1):.1f}',
                                              f'{round(lb_alg,3):.3f}',
                                              f'{round(x_true_prob,3):.3f}',
                                              num_iter['add'], 
                                              num_iter['remove'],
                                              num_iter['clean'],
                                              num_sol,
                                              num_scen_best,
                                              num_scen_max,
                                              f'{round(num_scen_avg,1):.1f}',
                                              f'{round(time_best_found, 0):.0f}']

        run_count += 1
        print("Completed run: " + str(run_count))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17524/978327033.py in <module>
#      44     for random_seed in random_seed_settings:
#      45
# ---> 46         runtime_search, num_iter, solutions = rs.search_alg(data_train, N_test, beta, alpha, time_limit_search, time_limit_solve,
#      47                                                            max_nr_solutions, add_strategy, remove_strategy, clean_strategy,
#      48                                                            add_remove_threshold, clean_time_threshold,
#
# ~\OneDrive - UvA\Research\Paper with Guan\Code\SamplingRobust\Code\robust_sampling.py in search_alg(data_train, N_test, beta, alpha, time_limit_search, time_limit_solve, max_nr_solutions, add_strategy, remove_strategy, clean_strategy, add_remove_threshold, clean_time_threshold, par, phi_div, phi_dot, numeric_precision, solve_SCP, uncertain_constraint, seed)
#      30     while True:
#      31         solve_start_time = time.time()
# ---> 32         [x, obj] = solve_SCP(Z_values, time_limit_solve)
#      33         solve_time = time.time() - solve_start_time
#      34
#
# ~\AppData\Local\Temp/ipykernel_17524/399504856.py in solve_SCP(S, time_limit)
#      19     prob = cp.Problem(obj,constraints)
#      20     try:
# ---> 21         prob.solve(solver=cp.MOSEK, mosek_params = {mosek.dparam.optimizer_max_time: time_limit})
#      22     except cp.error.SolverError:
#      23         return (None, None)
#
# ~\Anaconda3\lib\site-packages\cvxpy\problems\problem.py in solve(self, *args, **kwargs)
#     479         else:
#     480             solve_func = Problem._solve
# --> 481         return solve_func(self, *args, **kwargs)
#     482
#     483     @classmethod
#
# ~\Anaconda3\lib\site-packages\cvxpy\problems\problem.py in _solve(self, solver, warm_start, verbose, gp, qcp, requires_grad, enforce_dpp, ignore_dpp, **kwargs)
#    1005                 return self.value
#    1006
# -> 1007         data, solving_chain, inverse_data = self.get_problem_data(
#    1008             solver, gp, enforce_dpp, ignore_dpp, verbose)
#    1009
#
# ~\Anaconda3\lib\site-packages\cvxpy\problems\problem.py in get_problem_data(self, solver, gp, enforce_dpp, ignore_dpp, verbose)
#     653                          'Compiling problem (target solver=%s).', solver_name)
#     654                 s.LOGGER.info('Reduction chain: %s', reduction_chain_str)
# --> 655             data, inverse_data = solving_chain.apply(self, verbose)
#     656             safe_to_cache = (
#     657                 isinstance(data, dict)
#
# ~\Anaconda3\lib\site-packages\cvxpy\reductions\chain.py in apply(self, problem, verbose)
#      74             if verbose:
#      75                 s.LOGGER.info('Applying reduction %s', type(r).__name__)
# ---> 76             problem, inv = r.apply(problem)
#      77             inverse_data.append(inv)
#      78         return problem, inverse_data
#
# ~\Anaconda3\lib\site-packages\cvxpy\reductions\solvers\conic_solvers\mosek_conif.py in apply(self, problem)
#     182             data, inv_data = Slacks.apply(problem, [a2d.NONNEG])
#     183         else:
# --> 184             data, inv_data = Dualize.apply(problem)
#     185             # need to do more to handle SDP.
#     186             A, c, K = data[s.A], data[s.C], data['K_dir']
#
# ~\Anaconda3\lib\site-packages\cvxpy\reductions\cone2cone\affine2direct.py in apply(problem)
#      94     @staticmethod
#      95     def apply(problem):
# ---> 96         c, d, A, b = problem.apply_parameters()
#      97         Kp = problem.cone_dims  # zero, nonneg, exp, soc, psd
#      98         Kd = {
#
# ~\Anaconda3\lib\site-packages\cvxpy\reductions\dcp2cone\cone_matrix_stuffing.py in apply_parameters(self, id_to_param_value, zero_offset, keep_zeros)
#     174             if np.prod(self.A.shape) != 0:
#     175                 reduced_A, indices, indptr, shape = (
# --> 176                     canonInterface.reduce_problem_data_tensor(
#     177                         self.A, self.x.size))
#     178                 self.reduced_A = reduced_A
#
# ~\Anaconda3\lib\site-packages\cvxpy\cvxcore\python\canonInterface.py in reduce_problem_data_tensor(A, var_length, quad_form)
#     111     A_coo = A.tocoo()
#     112
# --> 113     unique_old_row, reduced_row = np.unique(A_coo.row, return_inverse=True)
#     114     reduced_A_shape = (unique_old_row.size, A_coo.shape[1])
#     115
#
# <__array_function__ internals> in unique(*args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py in unique(ar, return_index, return_inverse, return_counts, axis)
#     260     ar = np.asanyarray(ar)
#     261     if axis is None:
# --> 262         ret = _unique1d(ar, return_index, return_inverse, return_counts)
#     263         return _unpack_tuple(ret)
#     264
#
# ~\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py in _unique1d(ar, return_index, return_inverse, return_counts)
#     318
#     319     if optional_indices:
# --> 320         perm = ar.argsort(kind='mergesort' if return_index else 'quicksort')
#     321         aux = ar[perm]
#     322     else:
#
# KeyboardInterrupt:

# %%
dataio.write_output_to_latex(2, headers, output_data)
# Out:
# \begin{table}[H]
# \centering
# \resizebox{\linewidth}{!}{\begin{tabular}{ll|rrrrrrrrrrrrr}
# N_train & seed & Obj.~Alg. & Obj.~(true prob.) & Gap (\%) & LB & True Prob. & \#Iter.~(add) & \#Iter.~(remove) & \#Iter.~(clean) & $|\mathcal{X}|$ & $|\mathcal{S}_{best}|$ & $|\mathcal{S}_{max}|$ & $|\mathcal{S}_{avg}|$ & Time until best found\\
# \hline
# 100 & 1 & 1.418 & 1.222 & -16.1 & 0.907 & 0.913 & 70 & 48 & 0 & 118 & 26 & 27 & 22.7 & 14 \\
# 100 & 2 & 1.418 & 1.222 & -16.1 & 0.907 & 0.913 & 72 & 48 & 0 & 120 & 25 & 26 & 21.9 & 22 \\
# 100 & 3 & 1.418 & 1.222 & -16.0 & 0.907 & 0.914 & 74 & 54 & 0 & 128 & 22 & 23 & 19.8 & 7 \\
# 10000 & 1 & 1.204 & 1.222 & 1.5 & 0.951 & 0.954 & 70 & 44 & 0 & 114 & 25 & 28 & 22.2 & 25 \\
# 10000 & 2 & 1.204 & 1.222 & 1.5 & 0.950 & 0.954 & 67 & 22 & 0 & 89 & 43 & 46 & 31.3 & 57 \\
# 10000 & 3 & 1.203 & 1.222 & 1.6 & 0.951 & 0.954 & 60 & 32 & 0 & 92 & 31 & 34 & 25.2 & 23 \\
# \end{tabular}}
# \caption{}
# \label{}
# \end{table}

# %%
output_file_name = 'new_output2'

# %%
# Write output to .txt file
with open(r'output/'+output_file_name+'.txt','w+') as f:
    f.write(str(output_data))

# %%
# Read from .txt file
file_path = 'output/'+output_file_name+'.txt'
dic = ''
with open(file_path,'r') as f:
         for i in f.readlines():
            dic=i #string
output_data_read_2 = eval(dic)

# %%
# To plot histograms for random seed output
# Read from .txt file
output_file_name = 'new_output'
file_path = 'output/'+output_file_name+'.txt'
dic = ''
with open(file_path,'r') as f:
         for i in f.readlines():
            dic=i #string
output_data_read = eval(dic)

df = pd.DataFrame.from_dict(output_data_read, orient='index')
#li1 = [col for col in df.columns if 'add + improve' == col[1]]

df2 = pd.DataFrame({key: pd.Series(val) for key, val in output_data_read.items() if key[1] == 'add + improve + remove'})
obj2 = df2.iloc[0,:].astype(float)

title = 'Distribution of best found solution objective for random add + improve + remove'# for $\beta = 0.95$, $\alpha=10^{-6}$, $N_{1} = 1,000$, $N_{2} = 10,000$ and time limit $\mathcal{L} = 1$ minute'
dataio.plot_hist(obj2, 'Gap (%)', 'Frequency', title, 20, 0.75)
